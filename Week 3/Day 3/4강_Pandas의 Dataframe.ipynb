# %% [markdown]
# # 4강. Pandas의 Dataframe

# %% [markdown]
# ## dataframe
# > 2-D labeled **table**
#
# - 인덱스를 지정할 수 있음
# - numpy.Series와 다르게 dtype이 달라도 가능.

# %%
import pandas as pd

d = {'height': [1, 2, 3 , 4], 'weight': [30, 40, 50, 60]}

df = pd.DataFrame(d)

df
# Out:
#    height  weight
# 0       1      30
# 1       2      40
# 2       3      50
# 3       4      60

# %%
# dtype 확인

df.dtypes
# Out:
# height    int64
# weight    int64
# dtype: object

# %% [markdown]
# ## From CSV to DataFrame
# > CSV(Comma Seperated Value) 를 DataFrame으로 변환시킬 수 있다.
#
# - `.read_csv()`를 사용

# %%
# 파일 읽기
covid = pd.read_csv('./kaggle_COVID-19_Dataset/country_wise_latest.csv')

covid
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 3               Andorra        907      52        803      52         10
# 4                Angola        950      41        242     667         18
# ..                  ...        ...     ...        ...     ...        ...
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 3             0              0                5.73                  88.53
# 4             1              0                4.32                  25.47
# ..          ...            ...                 ...                    ...
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                      5.04                35526            737
# 1                      5.25                 4171            709
# 2                      6.17                23691           4282
# 3                      6.48                  884             23
# 4                     16.94                  749            201
# ..                      ...                  ...            ...
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 3                 2.60                 Europe
# 4                26.84                 Africa
# ..                 ...                    ...
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa
#
# [187 rows x 15 columns]

# %% [markdown]
# ## Pandas 활용 1. 일부분만 관찰하기

# %% [markdown]
# 1. `head(n)`: 처음 n개의 데이터 참조

# %%
# 위에서부터 5개를 관찰하는 방법(함수)

covid.head(3)
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa

# %% [markdown]
# 2. `tail(n)`: 처음 n개의 데이터 참조

# %%
covid.tail(5)
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 183      Western Sahara         10       1          8       1          0
# 184               Yemen       1691     483        833     375         10
# 185              Zambia       4552     140       2815    1597         71
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 182           2              0                0.73                  35.33
# 183           0              0               10.00                  80.00
# 184           4             36               28.56                  49.26
# 185           1            465                3.08                  61.84
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 182                    2.08                 8916           1705
# 183                   12.50                   10              0
# 184                   57.98                 1619             72
# 185                    4.97                 3326           1226
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 182              19.12  Eastern Mediterranean
# 183               0.00                 Africa
# 184               4.45  Eastern Mediterranean
# 185              36.86                 Africa
# 186              57.85                 Africa

# %% [markdown]
# ## Pandas 활용 2. 데이터 접근하기

# %% [markdown]
# 1. `df['column_name]` or `df.column_name`

# %%
covid['Active']
# Out:
# 0      9796
# 1      1991
# 2      7973
# 3        52
# 4       667
#        ...
# 182    6791
# 183       1
# 184     375
# 185    1597
# 186    2126
# Name: Active, Length: 187, dtype: int64

# %%
covid.Active
# Out:
# 0      9796
# 1      1991
# 2      7973
# 3        52
# 4       667
#        ...
# 182    6791
# 183       1
# 184     375
# 185    1597
# 186    2126
# Name: Active, Length: 187, dtype: int64

# %%
# covid.WHO Region
# 이 방법으로 접근가능한 경우는 순수한 문자열인 경우.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-e45ee06248e8> in <module>
# ----> 1 covid.WHO_Region
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'WHO_Region'

# %% [markdown]
# ### Tip!
# > DataFrame의 각 column은 **'Series'**다!

# %%
type(covid['Confirmed'])
# Out:
# pandas.core.series.Series

# %%
covid['Confirmed'][0]
# Out:
# 36263

# %%
covid['Confirmed'][1: 5]
# Out:
# 1     4880
# 2    27973
# 3      907
# 4      950
# Name: Confirmed, dtype: int64

# %% [markdown]
# ## Pandas 활용 3. '조건'을 이용해서 데이터 접근하기

# %%
# 1. 신규 확진자가 100명이 넘는 국가 찾아보기

covid['New cases'] > 100
# Out:
# 0       True
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 182     True
# 183    False
# 184    False
# 185    False
# 186     True
# Name: New cases, Length: 187, dtype: bool

# %%
covid[covid['New cases'] > 100]
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 0           Afghanistan      36263    1269      25198    9796        106
# 1               Albania       4880     144       2745    1991        117
# 2               Algeria      27973    1163      18837    7973        616
# 6             Argentina     167416    3059      72575   91782       4890
# 8             Australia      15303     167       9311    5825        368
# ..                  ...        ...     ...        ...     ...        ...
# 177      United Kingdom     301708   45844       1437  254427        688
# 179          Uzbekistan      21209     121      11674    9414        678
# 180           Venezuela      15988     146       9959    5883        525
# 182  West Bank and Gaza      10621      78       3752    6791        152
# 186            Zimbabwe       2704      36        542    2126        192
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0            10             18                3.50                  69.49
# 1             6             63                2.95                  56.25
# 2             8            749                4.16                  67.34
# 6           120           2057                1.83                  43.35
# 8             6            137                1.09                  60.84
# ..          ...            ...                 ...                    ...
# 177           7              3               15.19                   0.48
# 179           5            569                0.57                  55.04
# 180           4            213                0.91                  62.29
# 182           2              0                0.73                  35.33
# 186           2             24                1.33                  20.04
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                      5.04                35526            737
# 1                      5.25                 4171            709
# 2                      6.17                23691           4282
# 6                      4.21               130774          36642
# 8                      1.79                12428           2875
# ..                      ...                  ...            ...
# 177                 3190.26               296944           4764
# 179                    1.04                17149           4060
# 180                    1.47                12334           3654
# 182                    2.08                 8916           1705
# 186                    6.64                 1713            991
#
#      1 week % increase             WHO Region
# 0                 2.07  Eastern Mediterranean
# 1                17.00                 Europe
# 2                18.07                 Africa
# 6                28.02               Americas
# 8                23.13        Western Pacific
# ..                 ...                    ...
# 177               1.60                 Europe
# 179              23.67                 Europe
# 180              29.63               Americas
# 182              19.12  Eastern Mediterranean
# 186              57.85                 Africa
#
# [82 rows x 15 columns]

# %%
# 2. WHO 지역(WHO Region)이 동남아시아인 나라 찾기

covid['WHO Region'].unique()
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
covid[covid['WHO Region'] == 'South-East Asia']
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 13      Bangladesh     226225    2965     125683   97577       2772
# 19          Bhutan         99       0         86      13          4
# 27           Burma        350       6        292      52          0
# 79           India    1480073   33408     951166  495499      44457
# 80       Indonesia     100303    4838      58173   37292       1525
# 106       Maldives       3369      15       2547     807         67
# 119          Nepal      18752      48      13754    4950        139
# 158      Sri Lanka       2805      11       2121     673         23
# 167       Thailand       3297      58       3111     128          6
# 168    Timor-Leste         24       0          0      24          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 13           37           1801                1.31                  55.56
# 19            0              1                0.00                  86.87
# 27            0              2                1.71                  83.43
# 79          637          33598                2.26                  64.26
# 80           57           1518                4.82                  58.00
# 106           0             19                0.45                  75.60
# 119           3            626                0.26                  73.35
# 158           0             15                0.39                  75.61
# 167           0              2                1.76                  94.36
# 168           0              0                0.00                   0.00
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 13                     2.36               207453          18772
# 19                     0.00                   90              9
# 27                     2.05                  341              9
# 79                     3.51              1155338         324735
# 80                     8.32                88214          12089
# 106                    0.59                 2999            370
# 119                    0.35                17844            908
# 158                    0.52                 2730             75
# 167                    1.86                 3250             47
# 168                    0.00                   24              0
#
#      1 week % increase       WHO Region
# 13                9.05  South-East Asia
# 19               10.00  South-East Asia
# 27                2.64  South-East Asia
# 79               28.11  South-East Asia
# 80               13.70  South-East Asia
# 106              12.34  South-East Asia
# 119               5.09  South-East Asia
# 158               2.75  South-East Asia
# 167               1.45  South-East Asia
# 168               0.00  South-East Asia

# %% [markdown]
# ## Pandas 활용 4. 행을 기준으로 데이터 접근하기

# %%
# 예시 데이터 - 도서관 정보

books_dict = {'Available': [True, True, False], 'Location': [102, 215, 323], 'Genre': ['programming', 'Physics', 'Math']}

books_df = pd.DataFrame(books_dict, index=['버그란 무엇인가', '두근두근 물리학', '미분해줘 홈즈'])

books_df
# Out:
#           Available  Location        Genre
# 버그란 무엇인가       True       102  programming
# 두근두근 물리학       True       215      Physics
# 미분해줘 홈즈       False       323         Math

# %% [markdown]
# ### 인덱스를 이용해서 가져오기: `.loc[row, col]`

# %%
books_df.loc['버그란 무엇인가']
# Out:
# Available           True
# Location             102
# Genre        programming
# Name: 버그란 무엇인가, dtype: object

# %%
type(books_df.loc['버그란 무엇인가'])
# Out:
# pandas.core.series.Series

# %%
# '미분해줘 홈즈' 책이 대출가능한지 알고 싶다면?

books_df.loc['미분해줘 홈즈']['Available']
# Out:
# False

# %%
books_df.loc['미분해줘 홈즈', 'Available']
# Out:
# False

# %% [markdown]
# ### 숫자 인덱스를 이용해서 가져오기: `.iloc[row_idx, col_idx]`

# %%
# 인덱스 0행의 인덱스 1열 가지고오기

books_df.iloc[0, 1]
# Out:
# 102

# %%
# 인덱스 1행의 인덱스 0~1열 가지고오기

books_df.iloc[1, 0:2]
# Out:
# Available    True
# Location      215
# Name: 두근두근 물리학, dtype: object

# %% [markdown]
# ## Pandas 활용 5. groupby
# - Split: 특정한 '기준'을 바탕으로 DataFrame을 분할
# - Apply: 통계함수 sum(), mean(), median()을 적용해서 각 데이터를 압축
# - Combine: Apply된 결과를 바탕으로 새로운 Series를 생성 (group_key: applied_value)

# %% [markdown]
# 1. `groupby()`

# %%
covid.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# 1                    5.25                 4171            709
# 2                    6.17                23691           4282
# 3                    6.48                  884             23
# 4                   16.94                  749            201
#
#    1 week % increase             WHO Region
# 0               2.07  Eastern Mediterranean
# 1              17.00                 Europe
# 2              18.07                 Africa
# 3               2.60                 Europe
# 4              26.84                 Africa

# %%
# WHO Region 별 확진자수

# 1, covid에서 확진자 수 column만 추출
# 2. 이를 covid의 WHO Region을 기준으로 groupby한다

covid_by_region = covid['Confirmed'].groupby(by=covid['WHO Region'])

covid_by_region

# %%
covid_by_region.sum()
# Out:
# WHO Region
# Africa                    723207
# Americas                 8839286
# Eastern Mediterranean    1490744
# Europe                   3299523
# South-East Asia          1835297
# Western Pacific           292428
# Name: Confirmed, dtype: int64

# %%
# 국가당 감염자 수

covid_by_region.mean() # sum(): 국가 수
# Out:
# WHO Region
# Africa                    15066.812500
# Americas                 252551.028571
# Eastern Mediterranean     67761.090909
# Europe                    58920.053571
# South-East Asia          183529.700000
# Western Pacific           18276.750000
# Name: Confirmed, dtype: float64

# %% [markdown]
# ## 실습

# %% [markdown]
# 1. covid 데이터에서 100 case 대비 사망률(Deaths / 100 Cases)이 가장 높은 국가는?

# %%
cases = covid.loc[covid['Deaths / 100 Cases'].idxmax()]['Country/Region']

cases
# Out:
# 'Yemen'

# %% [markdown]
# 2. covid 데이터에서 신규 확진자가 없는 나라 중 WHO Region이 'Europe'인 나라를 모두 출력하면?
#     - Hint: 한 줄에 동시에 두 가지 조건을 Apply하는 경우 Warning이 발생할 수 있음.

# %%
covid[(covid['New cases'] == 0) & (covid['WHO Region'] == 'Europe')]
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  New cases  \
# 56         Estonia       2034      69       1923      42          0
# 75        Holy See         12       0         12       0          0
# 95          Latvia       1219      31       1045     143          0
# 100  Liechtenstein         86       1         81       4          0
# 113         Monaco        116       4        104       8          0
# 143     San Marino        699      42        657       0          0
# 157          Spain     272421   28432     150376   93613          0
#
#      New deaths  New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 56            0              1                3.39                  94.54
# 75            0              0                0.00                 100.00
# 95            0              0                2.54                  85.73
# 100           0              0                1.16                  94.19
# 113           0              0                3.45                  89.66
# 143           0              0                6.01                  93.99
# 157           0              0               10.44                  55.20
#
#      Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 56                     3.59                 2021             13
# 75                     0.00                   12              0
# 95                     2.97                 1192             27
# 100                    1.23                   86              0
# 113                    3.85                  109              7
# 143                    6.39                  699              0
# 157                   18.91               264836           7585
#
#      1 week % increase WHO Region
# 56                0.64     Europe
# 75                0.00     Europe
# 95                2.27     Europe
# 100               0.00     Europe
# 113               6.42     Europe
# 143               0.00     Europe
# 157               2.86     Europe

# %% [markdown]
# 3. 다음 [데이터](https://www.kaggle.com/neuromusic/avocado-prices)를 이용해 각 Region별로 아보카도가 가장 비싼 평균가격(AveragePrice)를 출력하면?

# %%
# 파일 읽기
avocado_prices = pd.read_csv('./Avocado_Prices/avocado.csv')

avocado_prices
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
avocado_prices.groupby('region').max('AveragePrice')
# Out:
#                      Unnamed: 0  AveragePrice  Total Volume         4046  \
# region
# Albany                       52          2.13     216738.47     34912.97
# Atlanta                      52          2.75     957792.07    553198.56
# BaltimoreWashington          52          2.28    1225103.27    202958.24
# Boise                        52          2.79     136377.55     69544.59
# Boston                       52          2.19     999783.13     85204.27
# BuffaloRochester             52          2.57     201142.55     26274.97
# California                   52          2.58   11213596.29   4794142.14
# Charlotte                    52          2.83     411160.94     95176.35
# Chicago                      52          2.30    1802646.35    378806.26
# CincinnatiDayton             52          2.20     538518.77    102019.45
# Columbus                     52          2.22     333398.29    140453.99
# DallasFtWorth                52          1.90    1885401.44   1013252.58
# Denver                       52          2.16    1381528.74    239163.63
# Detroit                      52          2.08     880540.45    214826.74
# GrandRapids                  52          2.73     408921.57      7888.33
# GreatLakes                   52          1.98    7094764.73   1410647.88
# HarrisburgScranton           52          2.27     395673.05    125847.54
# Nashville              45308.77      2780.00  2018
# NewOrleansMobile       43469.83     16675.00  2018
# NewYork               305309.26     18757.50  2018
# Northeast             640105.84     69794.85  2018
# NorthernNewEngland    154825.16      9655.00  2018
# Orlando               155928.30     19396.39  2018
# Philadelphia           54389.00      8255.40  2018
# PhoenixTucson         330583.10      6709.75  2018
# Pittsburgh             63248.94      6515.00  2018
# Plains                190573.14     52003.87  2018
# Portland              391141.49      7648.30  2018
# RaleighGreensboro      19822.48     10935.00  2018
# RichmondNorfolk        26710.36      9460.83  2018
# Roanoke                32938.52      5763.33  2018
# Sacramento              5504.02      7129.43  2018
# SanDiego              155614.62      5649.28  2018
# SanFrancisco           11823.61     10906.94  2018
# Seattle               312387.51      1943.12  2018
# SouthCarolina          70398.75     14585.00  2018
# SouthCentral         1049435.14    108072.79  2018
# Southeast            1318520.16     92787.50  2018
# Spokane                43887.36       331.90  2018
# StLouis                54426.61     18517.91  2018
# Syracuse               22305.58      3005.00  2018
# Tampa                 150133.37     15976.67  2018
# TotalUS              5719096.61    551693.65  2018
# West                 2838239.39     26564.17  2018
# WestTexNewMexico      287509.52     38120.00  2018

# %%
avocado_prices[avocado_prices['region'] == 'West']
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume        4046  \
# 2704            0  2015-12-27          0.83    5291979.63  2038443.68
# 2705            1  2015-12-20          0.88    4737649.03  2017331.24
# 2706            2  2015-12-13          0.85    4899439.92  1798995.46
# 2707            3  2015-12-06          0.75    6202513.84  2097720.52
# 2708            4  2015-11-29          0.99    3719603.21  1461861.54
# ...           ...         ...           ...           ...         ...
# 18232           7  2018-02-04          1.41     283378.47    22474.66
# 18233           8  2018-01-28          1.80     185974.53    22918.40
# 18234           9  2018-01-21          1.83     189317.99    27049.44
# 18235          10  2018-01-14          1.82     207999.67    33869.12
# 18236          11  2018-01-07          1.48     297190.60    34734.97
#
#              4225       4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 2704   1717599.45  125254.82  1410681.68   838267.79   567269.76      5144.13
# 2705   1314711.00  130849.60  1274757.19   843691.13   417746.45     13319.61
# 2706   1596329.01  134101.62  1370013.83   851506.76   517936.19       570.88
# 2707   2051392.83  107568.34  1945832.15  1360760.83   582846.33      2224.99
# 2708   1216811.00  104219.76   936710.91   688674.00   247318.15       718.76
# ...           ...        ...         ...         ...         ...          ...
# 18232    55360.49     133.41   205409.91    70232.59   134666.91       510.41
# 18233    33051.14      93.52   129911.47    77822.23    51986.86       102.38
# 18234    33561.32     439.47   128267.76    76091.99    51947.50       228.27
# 18235    47435.14     433.52   126261.89    89115.78    37133.99        12.12
# 18236    62967.74     157.77   199330.12   103761.55    95544.39        24.18
#
#                type  year region
# 2704   conventional  2015   West
# 2705   conventional  2015   West
# 2706   conventional  2015   West
# 2707   conventional  2015   West
# 2708   conventional  2015   West
# ...             ...   ...    ...
# 18232       organic  2018   West
# 18233       organic  2018   West
# 18234       organic  2018   West
# 18235       organic  2018   West
# 18236       organic  2018   West
#
# [338 rows x 14 columns]
