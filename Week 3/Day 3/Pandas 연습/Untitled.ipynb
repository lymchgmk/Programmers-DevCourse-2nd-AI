# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../kaggle_COVID-19_Dataset/country_wise_latest.csv")

df.head()
# Out:
#   Country/Region  Confirmed  Deaths  Recovered  Active  New cases  New deaths  \
# 0    Afghanistan      36263    1269      25198    9796        106          10
# 1        Albania       4880     144       2745    1991        117           6
# 2        Algeria      27973    1163      18837    7973        616           8
# 3        Andorra        907      52        803      52         10           0
# 4         Angola        950      41        242     667         18           1
#
#    New recovered  Deaths / 100 Cases  Recovered / 100 Cases  \
# 0             18                3.50                  69.49
# 1             63                2.95                  56.25
# 2            749                4.16                  67.34
# 3              0                5.73                  88.53
# 4              0                4.32                  25.47
#
#    Deaths / 100 Recovered  Confirmed last week  1 week change  \
# 0                    5.04                35526            737
# ...

# %%
tmp = df.copy()

# %%
s1 = tmp.groupby(by='WHO Region', as_index=False)

# %%
s1.min()
# Out:
#               WHO Region       Country/Region  Confirmed  Deaths  Recovered  \
# 0                 Africa              Algeria         10       0          0
# 1               Americas  Antigua and Barbuda         17       0          0
# 2  Eastern Mediterranean          Afghanistan        674      11          0
# 3                 Europe              Albania         12       0          0
# 4        South-East Asia           Bangladesh         24       0          0
# 5        Western Pacific            Australia         20       0         11
#
#    Active  New cases  New deaths  New recovered  Deaths / 100 Cases  \
# 0       1          0           0              0                0.00
# 1       0          0           0              0                0.00
# 2      24          3           0              0                0.15
# 3       0          0           0              0                0.00
# 4      13          0           0              0                0.00
# ...

# %%
s1.max()
# Out:
#                       Country/Region  Confirmed  Deaths  Recovered   Active  \
# WHO Region
# Africa                      Zimbabwe     452529    7067     274925   170537
# Americas                   Venezuela    4290259  148011    1846641  2816444
# Eastern Mediterranean          Yemen     293606   15912     255144    52992
# Europe                    Uzbekistan     816680   45844     602249   254427
# South-East Asia          Timor-Leste    1480073   33408     951166   495499
# Western Pacific              Vietnam      86783    4656      78869    53649
#
#                        New cases  New deaths  New recovered  \
# WHO Region
# Africa                      7096         298           9848
# Americas                   56336        1076          33728
# Eastern Mediterranean       2553         212           3592
# Europe                      5607          85           3077
# South-East Asia            44457         637          33598
# ...

# %%
s2 = tmp.groupby(['WHO Region', 'Country/Region'], as_index=False).agg([max, min])

# %%
s2
# Out:
#                                Confirmed        Deaths       Recovered         \
#                                      max    min    max   min       max    min
# WHO Region      Country/Region
# Africa          Algeria            27973  27973   1163  1163     18837  18837
#                 Angola               950    950     41    41       242    242
#                 Benin               1770   1770     35    35      1036   1036
#                 Botswana             739    739      2     2        63     63
#                 Burkina Faso        1100   1100     53    53       926    926
# ...                                  ...    ...    ...   ...       ...    ...
# Western Pacific Philippines        82040  82040   1945  1945     26446  26446
#                 Singapore          50838  50838     27    27     45692  45692
#                 South Korea        14203  14203    300   300     13007  13007
#                 Taiwan*              462    462      7     7       440    440
# ...
